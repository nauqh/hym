# %%
import pandas as pd
from app.utils.riot import RiotAPI

# %%
puuid = '8UIhStkspIglog9paowA4mXzlckT-xySwWNIFac3o2ojumva9ffkFMda_jGpW_hhInKWpvUp5pPPrA'
api = RiotAPI('RGAPI-a384a673-d288-42ec-a860-55a1602dba94')

api.get_puuid("Tupac Shaco", "MSA")
# Out:
# 'mqbacQ9cIaJvbiKvr5AXRyYZOH626GPbta6YADBb0zroxI7FlgPBibZtwzIsO4PfcOTBw4njgPfkrA'

# %%
puuid = '8UIhStkspIglog9paowA4mXzlckT-xySwWNIFac3o2ojumva9ffkFMda_jGpW_hhInKWpvUp5pPPrA'
TOKEN = 'RGAPI-a384a673-d288-42ec-a860-55a1602dba94'
api = RiotAPI(TOKEN)

puuids = {
        'tuandao1311': '8UIhStkspIglog9paowA4mXzlckT-xySwWNIFac3o2ojumva9ffkFMda_jGpW_hhInKWpvUp5pPPrA',
        'cozybearrrrr': 'mh3B8Naz1MbJ6RE7dJTu3ZCLh7Rwo6CCJQiA-fVlLXUuQmkibMVMztpCLALJMMJQm4QOevN1-u0lnA',
        'tuanardo': 'DV0Aad31H16g3lItoojolWMPZQYOj0l90KzVSUV-qF3QlF92hOC_WLLssdR1MqPS-3UMEKp0Mn5woA',
        'nauqh': 'aTa5_43m0w8crNsi-i9nxGpSVU06WZBuK-h9bZEOK0g_lJox3XF4Dv4BzVwZieRj0QwlGnJ4SZbftg',
        'wavepin': 'idASdW5eSrO5Oih-ViK07RdeXE33JM1Mm3FwV7JiveTwbqfjl1vQUvToJ95c1B4EeQd8BAZgXkGSUw'
    }
puuids.values()
# Out:
# dict_values(['8UIhStkspIglog9paowA4mXzlckT-xySwWNIFac3o2ojumva9ffkFMda_jGpW_hhInKWpvUp5pPPrA', 'mh3B8Naz1MbJ6RE7dJTu3ZCLh7Rwo6CCJQiA-fVlLXUuQmkibMVMztpCLALJMMJQm4QOevN1-u0lnA', 'DV0Aad31H16g3lItoojolWMPZQYOj0l90KzVSUV-qF3QlF92hOC_WLLssdR1MqPS-3UMEKp0Mn5woA', 'aTa5_43m0w8crNsi-i9nxGpSVU06WZBuK-h9bZEOK0g_lJox3XF4Dv4BzVwZieRj0QwlGnJ4SZbftg', 'idASdW5eSrO5Oih-ViK07RdeXE33JM1Mm3FwV7JiveTwbqfjl1vQUvToJ95c1B4EeQd8BAZgXkGSUw'])

# %%
ids = api.get_match_ids(puuid, 20, queue_id=450)

for id in ids:
    match_data = api.get_match_data(id)
    match_puuids = match_data['metadata']['participants']
    if all(puuid in match_puuids for puuid in puuids.values()):
        df = pd.DataFrame(match_data['info']['participants'])
        break

df
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 4
#       1 ids = api.get_match_ids(puuid, 20, queue_id=450)
#       3 for id in ids:
# ----> 4     match_data = api.get_match_data(id)
#       5     match_puuids = match_data['metadata']['participants']
#       6     if all(puuid in match_puuids for puuid in puuids.values()):
#
# File d:\Laboratory\V2 2024\porostream\app\utils\riot.py:49, in RiotAPI.get_match_data(self, match_id)
#      47 def get_match_data(self, match_id) -> dict:
#      48     url = f"https://sea.api.riotgames.com/lol/match/v5/matches/{match_id}?api_key={self.token}"
# ---> 49     match_data = self._make_request(url)
#      50     return match_data
#
# File d:\Laboratory\V2 2024\porostream\app\utils\riot.py:12, in RiotAPI._make_request(self, url)
#      10 def _make_request(self, url):
#      11     while True:
# ...

# %%
import pandas as pd

df = pd.read_csv('app/data/100games.csv')
df.head()
# Out:
#    allInPings  assistMePings  assists  baronKills  basicPings  bountyLevel  \
# 0           0              0       12           0           0           13
# 1           0              1       30           0           0            0
# 2           0              1       35           0           0           16
# 3           0              3       20           0           0           17
# 4           0              0       33           0           0           22
#
#    champExperience  champLevel  championId championName  ...  \
# 0            17994          17         234        Viego  ...
# 1            17866          17         412       Thresh  ...
# 2            27995          18           8     Vladimir  ...
# 3            20391          18          24          Jax  ...
# 4            27999          18         234        Viego  ...
#
#                                    info.participants  info.platformId  \
# 0  [{'allInPings': 0, 'assistMePings': 0, 'assist...              VN2
# ...

# %%
df['riotIdGameName'] = df['puuid'].map({
        '8UIhStkspIglog9paowA4mXzlckT-xySwWNIFac3o2ojumva9ffkFMda_jGpW_hhInKWpvUp5pPPrA': 'tuandao1311',
        'mh3B8Naz1MbJ6RE7dJTu3ZCLh7Rwo6CCJQiA-fVlLXUuQmkibMVMztpCLALJMMJQm4QOevN1-u0lnA': 'cozybearrrrr',
        'DV0Aad31H16g3lItoojolWMPZQYOj0l90KzVSUV-qF3QlF92hOC_WLLssdR1MqPS-3UMEKp0Mn5woA': 'tuanancom',
        'aTa5_43m0w8crNsi-i9nxGpSVU06WZBuK-h9bZEOK0g_lJox3XF4Dv4BzVwZieRj0QwlGnJ4SZbftg': 'nauqh',
        'idASdW5eSrO5Oih-ViK07RdeXE33JM1Mm3FwV7JiveTwbqfjl1vQUvToJ95c1B4EeQd8BAZgXkGSUw': 'wavepin'
    })
df['riotIdGameName']
# Out:
# 0      tuandao1311
# 1      tuandao1311
# 2      tuandao1311
# 3      tuandao1311
# 4      tuandao1311
#           ...
# 495        wavepin
# 496        wavepin
# 497        wavepin
# 498        wavepin
# 499        wavepin
# Name: riotIdGameName, Length: 500, dtype: object
